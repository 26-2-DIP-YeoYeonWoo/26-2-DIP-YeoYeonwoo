# %% [markdown]
# <a href="https://colab.research.google.com/github/26-2-DIP-YeoYeonWoo/26-2-DIP-YeoYeonwoo/blob/main/notebook_2026/Lab00_ImageLoad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # My Homework #0
# - 야간 경복궁 산책

# %%
I = plt.imread('/content/KakaoTalk_20260919_015300433.jpg')
print(I.dtype, I.shape)
plt.imshow(I)
plt.title('A wonderful place to refresh')
plt.show()
# Out:
# uint8 (4284, 5712, 3)

# %% [markdown]
# - Image file의 metadata를 확인하기

# %%
from PIL import Image
from PIL.ExifTags import TAGS

# %%
I = Image.open('/content/KakaoTalk_20260919_015300433.jpg')
exifdata = I.getexif()
for tag_id in exifdata:
    tag = TAGS.get(tag_id, tag_id)
    data = exifdata.get(tag_id)
    print(f"{tag:25}: {data}")
# Out:
# GPSInfo                  : 2674
# ResolutionUnit           : 2
# ExifOffset               : 228
# Make                     : Apple
# Model                    : iPhone 16
# Software                 : 26.6.2
# Orientation              : 6
# DateTime                 : 2026:09:16 20:17:15
# YCbCrPositioning         : 1
# XResolution              : 72.0
# YResolution              : 72.0
# HostComputer             : iPhone 16
